# %%
import geopandas as gpd

gdf = gpd.read_parquet('/Users/arthurcalvi/Repo/Disturbance-Attribution-Dataset-Joining/data/results/clusters/clusters_polygons_d2_r100_g5_600m_360d_v0.4.parquet')

# %%
gdf
# Out:
#              id start_date   end_date      class    dataset  tree_type  \
# 261894  1643655 2017-01-01 2017-12-31      Other  senfseidl  Broadleaf
# 261896  1643657 2017-01-01 2017-12-31      Other  senfseidl  Broadleaf
# 69153     56769 2018-01-01 2018-12-31      Other  senfseidl  Broadleaf
# 69154     56770 2018-01-01 2018-12-31      Other  senfseidl  Broadleaf
# 69155     56771 2018-01-01 2018-12-31      Other  senfseidl  Broadleaf
# ...         ...        ...        ...        ...        ...        ...
# 740061    20397 2019-09-01 2020-05-01  clear-cut      forms       None
# 467428  2122253 2020-01-01 2020-12-31      Other  senfseidl  Broadleaf
# 241904  1619187 2017-01-01 2017-12-31      Other  senfseidl      Mixed
# 241906  1619190 2017-01-01 2017-12-31      Other  senfseidl  Broadleaf
# 753531    33867 2018-09-01 2019-05-01  clear-cut      forms       None
#
#              essence                                           geometry  \
# ...
